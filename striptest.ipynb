# %% [markdown]
# # Tester

# %%
import numpy as np

### begin-solution
# this will be gone
p = np.arange(0,10,1)

### end-solution

# but this not
print('nothing')

# %%
### begin-solution
# deze cel is helemaal leeg.
### end-solution

# %% [markdown]
# ## Of in een markdown cell
# Waarbij dit weergegeven wordt
# ### begin-solution
# maar dit niet
# ### end-solution
#
# en deze dan?
# ```{solution} ex-brownian-1
# ### begin-solution
# dit wordt weggehaald
# ### end-solution
# maar dit niet
# ```
